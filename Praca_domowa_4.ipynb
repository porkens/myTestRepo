# %% [markdown]
# <a href="https://colab.research.google.com/github/porkens/myTestRepo/blob/main/Praca_domowa_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta

from keras.utils.vis_utils import plot_model
from IPython.display import Image 
from keras.preprocessing.image import ImageDataGenerator

from keras.callbacks import EarlyStopping

# install optuna
! pip install optuna

import optuna


batch_size = 128
num_classes = 10
epochs = 50

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (20.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (1.0.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.3)
# Requirement already satisfied: cliff in /usr/local/lib/python3.6/dist-packages (from optuna) (3.5.0)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.20)
# Requirement already satisfied: cmaes>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (0.7.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna) (4.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.19.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.1.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.0.4)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2!=0.8.3,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.15.0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (5.5.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna) (3.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (1.8.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (20.3.0)
# Requirement already satisfied: colorama>=0.3.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.7.4.3)
# 60000 train samples
# 10000 test samples

# %%
N_TRAIN_EXAMPLES = 1000 #3000
N_TEST_EXAMPLES = 10000
x_train = x_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# %%
def c_model():
  # Our old fully connected (dense) network
  #model = Sequential()
  #model.add(Dense(512, activation='relu', input_shape=(784,)))
  #model.add(Dropout(0.2))
  #model.add(Dense(512, activation='relu'))
  #model.add(Dropout(0.2))
  #model.add(Dense(512, activation='relu'))
  #model.add(Dropout(0.2))
  #model.add(Dense(num_classes, activation='softmax'))
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes, activation='softmax'))

  return model

# %%
def objective(trial):
  
  rotation_range=trial.suggest_uniform('rotation_range', .00,30)
  zoom_range=trial.suggest_uniform('zoom_range', .00,0.30)
  shift_range=trial.suggest_uniform('shift_range', .00,0.20)
  
  datagen = ImageDataGenerator( 
    rotation_range=rotation_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    zoom_range=zoom_range
    )

  model = c_model()

  from keras.callbacks import EarlyStopping

  model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])
  
  e_s=EarlyStopping(monitor='val_accuracy', patience=12, verbose=1)

  history = model.fit(datagen.flow(x_train, y_train,
                    batch_size=batch_size),
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=0,
                    validation_data=(x_test, y_test), 
                    callbacks=[e_s])

  score = model.evaluate(x_test, y_test,verbose=0)

  return score[1]

# %%
study = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner(), sampler=optuna.samplers.TPESampler() )
study.optimize(objective, n_trials=30, timeout=1200)
# Out:
# [I 2020-12-20 21:15:16,401] A new study created in memory with name: no-name-e4cf414a-5f22-43e7-9e3e-367d234fbed4
# [I 2020-12-20 21:15:48,749] Trial 0 finished with value: 0.9739000201225281 and parameters: {'rotation_range': 24.000028531130255, 'zoom_range': 0.11163453364869926, 'shift_range': 0.0307731257699869}. Best is trial 0 with value: 0.9739000201225281.
# [I 2020-12-20 21:16:17,385] Trial 1 finished with value: 0.9660999774932861 and parameters: {'rotation_range': 11.408026717949875, 'zoom_range': 0.1813207941391939, 'shift_range': 0.17733988627259437}. Best is trial 0 with value: 0.9739000201225281.
# Epoch 00049: early stopping
# [I 2020-12-20 21:16:45,561] Trial 2 finished with value: 0.9656999707221985 and parameters: {'rotation_range': 15.492465425956457, 'zoom_range': 0.005564512270242605, 'shift_range': 0.01845913968242836}. Best is trial 0 with value: 0.9739000201225281.
# [I 2020-12-20 21:17:14,181] Trial 3 finished with value: 0.9732999801635742 and parameters: {'rotation_range': 26.73129059009123, 'zoom_range': 0.22793290877134986, 'shift_range': 0.012304830606921002}. Best is trial 0 with value: 0.9739000201225281.
# [I 2020-12-20 21:17:42,909] Trial 4 finished with value: 0.9672999978065491 and parameters: {'rotation_range': 24.32419495134693, 'zoom_range': 0.002552979425105617, 'shift_range': 0.012731787602493895}. Best is trial 0 with value: 0.9739000201225281.
# [I 2020-12-20 21:18:11,590] Trial 5 finished with value: 0.9760000109672546 and parameters: {'rotation_range': 18.15541906297938, 'zoom_range': 0.12976827127750343, 'shift_range': 0.08145056373443534}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:18:40,599] Trial 6 finished with value: 0.9758999943733215 and parameters: {'rotation_range': 18.93351155769338, 'zoom_range': 0.19580180149839227, 'shift_range': 0.07728583118292826}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:19:09,012] Trial 7 finished with value: 0.9646999835968018 and parameters: {'rotation_range': 13.959186667001001, 'zoom_range': 0.29496511393300956, 'shift_range': 0.18995095853697358}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:19:37,620] Trial 8 finished with value: 0.9742000102996826 and parameters: {'rotation_range': 11.374371269865177, 'zoom_range': 0.01660916421228197, 'shift_range': 0.09126984458605053}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:20:06,164] Trial 9 finished with value: 0.9708999991416931 and parameters: {'rotation_range': 14.980776850928125, 'zoom_range': 0.06512828636682376, 'shift_range': 0.12728777017079}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:20:34,678] Trial 10 finished with value: 0.9695000052452087 and parameters: {'rotation_range': 0.8387785704632229, 'zoom_range': 0.11927205571441521, 'shift_range': 0.13748755266671517}. Best is trial 5 with value: 0.9760000109672546.
# [I 2020-12-20 21:21:02,905] Trial 11 finished with value: 0.9776999950408936 and parameters: {'rotation_range': 20.676516120079068, 'zoom_range': 0.2045277622518482, 'shift_range': 0.07073156252058342}. Best is trial 11 with value: 0.9776999950408936.
# [I 2020-12-20 21:21:31,171] Trial 12 finished with value: 0.9771999716758728 and parameters: {'rotation_range': 20.319924413207474, 'zoom_range': 0.2461671852311435, 'shift_range': 0.055772929554184905}. Best is trial 11 with value: 0.9776999950408936.
# [I 2020-12-20 21:21:59,313] Trial 13 finished with value: 0.9772999882698059 and parameters: {'rotation_range': 20.713285814397615, 'zoom_range': 0.273248708199848, 'shift_range': 0.0522813234503821}. Best is trial 11 with value: 0.9776999950408936.
# [I 2020-12-20 21:22:27,773] Trial 14 finished with value: 0.9811999797821045 and parameters: {'rotation_range': 28.606378433144908, 'zoom_range': 0.2983034338822881, 'shift_range': 0.0540652872078074}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:22:56,154] Trial 15 finished with value: 0.9739999771118164 and parameters: {'rotation_range': 29.125816330132288, 'zoom_range': 0.28776719277624196, 'shift_range': 0.11255829805684547}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:23:24,459] Trial 16 finished with value: 0.9743000268936157 and parameters: {'rotation_range': 5.859090976147101, 'zoom_range': 0.17818573846075714, 'shift_range': 0.04897571428305589}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:23:53,145] Trial 17 finished with value: 0.9751999974250793 and parameters: {'rotation_range': 26.93703274972159, 'zoom_range': 0.2323503349699998, 'shift_range': 0.06971550429329366}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:24:21,389] Trial 18 finished with value: 0.97079998254776 and parameters: {'rotation_range': 29.738112937623956, 'zoom_range': 0.2539546868129648, 'shift_range': 0.1051006096168079}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:24:49,574] Trial 19 finished with value: 0.9789000153541565 and parameters: {'rotation_range': 23.586024528851333, 'zoom_range': 0.2147955025095985, 'shift_range': 0.03503638939178519}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:25:17,828] Trial 20 finished with value: 0.9725000262260437 and parameters: {'rotation_range': 24.3151172092519, 'zoom_range': 0.15575314837175433, 'shift_range': 0.03450045425380427}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:25:45,941] Trial 21 finished with value: 0.9764999747276306 and parameters: {'rotation_range': 22.937666981983973, 'zoom_range': 0.20904388447492006, 'shift_range': 0.06483648226109251}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:26:14,141] Trial 22 finished with value: 0.9763000011444092 and parameters: {'rotation_range': 27.2094430976644, 'zoom_range': 0.21224809387955854, 'shift_range': 0.037105166309851986}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:26:42,122] Trial 23 finished with value: 0.9739999771118164 and parameters: {'rotation_range': 22.022083436406277, 'zoom_range': 0.26970613930960585, 'shift_range': 0.0029972503936362693}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:27:10,176] Trial 24 finished with value: 0.9764000177383423 and parameters: {'rotation_range': 18.020985129853184, 'zoom_range': 0.15538569505597763, 'shift_range': 0.08906958800922443}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:27:38,124] Trial 25 finished with value: 0.9714000225067139 and parameters: {'rotation_range': 29.230145628029256, 'zoom_range': 0.08692685516007179, 'shift_range': 0.04221864562880218}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:28:06,155] Trial 26 finished with value: 0.9733999967575073 and parameters: {'rotation_range': 25.721405450307362, 'zoom_range': 0.29918642380482885, 'shift_range': 0.06280944118144993}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:28:34,405] Trial 27 finished with value: 0.9725000262260437 and parameters: {'rotation_range': 21.539798009427003, 'zoom_range': 0.17438708793297156, 'shift_range': 0.022776042525941828}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:29:03,203] Trial 28 finished with value: 0.972000002861023 and parameters: {'rotation_range': 29.981419578849646, 'zoom_range': 0.25779512359965645, 'shift_range': 0.0005974325415196297}. Best is trial 14 with value: 0.9811999797821045.
# [I 2020-12-20 21:29:31,436] Trial 29 finished with value: 0.9753000140190125 and parameters: {'rotation_range': 24.543803433276803, 'zoom_range': 0.22084367396569288, 'shift_range': 0.030338993117497937}. Best is trial 14 with value: 0.9811999797821045.

# %%
print("Number trials: {}".format(len(study.trials)))
print("Best trial:")
trial=study.best_trial
print("Value: {}".format(trial.value))
print("Params")
for key, value in trial.params.items():
  print("  {}:{}  ".format(key, value))
# Out:
# Number trials: 30
# Best trial:
# Value: 0.9811999797821045
# Params
#   rotation_range:28.606378433144908
#   zoom_range:0.2983034338822881
#   shift_range:0.0540652872078074

# %%
rotation_range=trial.params.get('rotation_range')
zoom_range=trial.params.get('zoom_range')
shift_range=trial.params.get('shift_range')

  
datagen = ImageDataGenerator( 
    rotation_range=rotation_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    zoom_range=zoom_range
    )

model = c_model()

from keras.callbacks import EarlyStopping

model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

e_s=EarlyStopping(monitor='val_accuracy',patience=12,verbose=1)

history = model.fit(datagen.flow(x_train, y_train,
                    batch_size=batch_size),
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[e_s])
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 99ms/step - loss: 2.2917 - accuracy: 0.1691 - val_loss: 2.1636 - val_accuracy: 0.3011
# Epoch 2/50
# 8/8 [==============================] - 1s 77ms/step - loss: 2.1336 - accuracy: 0.2731 - val_loss: 1.4486 - val_accuracy: 0.6102
# Epoch 3/50
# 8/8 [==============================] - 1s 75ms/step - loss: 1.7949 - accuracy: 0.4037 - val_loss: 1.0995 - val_accuracy: 0.6595
# Epoch 4/50
# 8/8 [==============================] - 1s 76ms/step - loss: 1.5575 - accuracy: 0.4562 - val_loss: 0.7605 - val_accuracy: 0.8003
# Epoch 5/50
# 8/8 [==============================] - 1s 77ms/step - loss: 1.3149 - accuracy: 0.5562 - val_loss: 0.5976 - val_accuracy: 0.8517
# Epoch 6/50
# 8/8 [==============================] - 1s 74ms/step - loss: 1.1701 - accuracy: 0.6382 - val_loss: 0.4353 - val_accuracy: 0.8866
# Epoch 7/50
# 8/8 [==============================] - 1s 74ms/step - loss: 1.0858 - accuracy: 0.6175 - val_loss: 0.3726 - val_accuracy: 0.9062
# Epoch 8/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.9454 - accuracy: 0.7121 - val_loss: 0.3496 - val_accuracy: 0.9010
# Epoch 9/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.9507 - accuracy: 0.6951 - val_loss: 0.2900 - val_accuracy: 0.9139
# Epoch 10/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.7953 - accuracy: 0.7321 - val_loss: 0.2481 - val_accuracy: 0.9282
# Epoch 11/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.7607 - accuracy: 0.7661 - val_loss: 0.2128 - val_accuracy: 0.9402
# Epoch 12/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.7177 - accuracy: 0.7711 - val_loss: 0.2035 - val_accuracy: 0.9369
# Epoch 13/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6994 - accuracy: 0.7709 - val_loss: 0.1936 - val_accuracy: 0.9440
# Epoch 14/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6064 - accuracy: 0.8093 - val_loss: 0.1850 - val_accuracy: 0.9403
# Epoch 15/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5885 - accuracy: 0.8015 - val_loss: 0.1800 - val_accuracy: 0.9457
# Epoch 16/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6291 - accuracy: 0.8009 - val_loss: 0.1738 - val_accuracy: 0.9443
# Epoch 17/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5162 - accuracy: 0.8363 - val_loss: 0.1307 - val_accuracy: 0.9588
# Epoch 18/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5035 - accuracy: 0.8529 - val_loss: 0.1431 - val_accuracy: 0.9539
# Epoch 19/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5139 - accuracy: 0.8468 - val_loss: 0.1237 - val_accuracy: 0.9606
# Epoch 20/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.4561 - accuracy: 0.8582 - val_loss: 0.1309 - val_accuracy: 0.9588
# Epoch 21/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4031 - accuracy: 0.8733 - val_loss: 0.1128 - val_accuracy: 0.9638
# Epoch 22/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3968 - accuracy: 0.8699 - val_loss: 0.1096 - val_accuracy: 0.9642
# Epoch 23/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.4005 - accuracy: 0.8788 - val_loss: 0.1181 - val_accuracy: 0.9629
# Epoch 24/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.4806 - accuracy: 0.8575 - val_loss: 0.0996 - val_accuracy: 0.9715
# Epoch 25/50
# 8/8 [==============================] - 1s 96ms/step - loss: 0.4080 - accuracy: 0.8778 - val_loss: 0.1110 - val_accuracy: 0.9651
# Epoch 26/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.4121 - accuracy: 0.8738 - val_loss: 0.1010 - val_accuracy: 0.9658
# Epoch 27/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3865 - accuracy: 0.8737 - val_loss: 0.0900 - val_accuracy: 0.9706
# Epoch 28/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3654 - accuracy: 0.8986 - val_loss: 0.0927 - val_accuracy: 0.9692
# Epoch 29/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2882 - accuracy: 0.9211 - val_loss: 0.0921 - val_accuracy: 0.9689
# Epoch 30/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3276 - accuracy: 0.9042 - val_loss: 0.0916 - val_accuracy: 0.9702
# Epoch 31/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3403 - accuracy: 0.8912 - val_loss: 0.0851 - val_accuracy: 0.9724
# Epoch 32/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.3231 - accuracy: 0.9028 - val_loss: 0.0872 - val_accuracy: 0.9720
# Epoch 33/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2963 - accuracy: 0.9053 - val_loss: 0.1120 - val_accuracy: 0.9653
# Epoch 34/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2729 - accuracy: 0.9126 - val_loss: 0.0841 - val_accuracy: 0.9735
# Epoch 35/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2797 - accuracy: 0.9120 - val_loss: 0.0862 - val_accuracy: 0.9716
# Epoch 36/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2627 - accuracy: 0.9142 - val_loss: 0.0788 - val_accuracy: 0.9746
# Epoch 37/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.3067 - accuracy: 0.9075 - val_loss: 0.0812 - val_accuracy: 0.9718
# Epoch 38/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2335 - accuracy: 0.9244 - val_loss: 0.0718 - val_accuracy: 0.9774
# Epoch 39/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.2868 - accuracy: 0.9028 - val_loss: 0.0757 - val_accuracy: 0.9765
# Epoch 40/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2453 - accuracy: 0.9160 - val_loss: 0.0784 - val_accuracy: 0.9743
# Epoch 41/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2360 - accuracy: 0.9139 - val_loss: 0.0740 - val_accuracy: 0.9747
# Epoch 42/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2859 - accuracy: 0.9154 - val_loss: 0.0718 - val_accuracy: 0.9766
# Epoch 43/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2563 - accuracy: 0.9265 - val_loss: 0.0747 - val_accuracy: 0.9759
# Epoch 44/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2745 - accuracy: 0.9148 - val_loss: 0.0765 - val_accuracy: 0.9746
# Epoch 45/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1823 - accuracy: 0.9515 - val_loss: 0.0704 - val_accuracy: 0.9769
# Epoch 46/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2645 - accuracy: 0.9303 - val_loss: 0.0723 - val_accuracy: 0.9769
# Epoch 47/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2494 - accuracy: 0.9296 - val_loss: 0.0726 - val_accuracy: 0.9769
# Epoch 48/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.2509 - accuracy: 0.9190 - val_loss: 0.0645 - val_accuracy: 0.9791
# Epoch 49/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.2191 - accuracy: 0.9264 - val_loss: 0.0605 - val_accuracy: 0.9800
# Epoch 50/50
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1887 - accuracy: 0.9445 - val_loss: 0.0684 - val_accuracy: 0.9773

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
print(x_train.reshape((len(x_train),img_rows, img_cols)).shape)
# see example augmentation images
fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow(X_batch[i].reshape((img_rows, img_cols)))
         plt.axis('off')
    plt.show()
    break
# Out:
# (1000, 28, 28)

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[4:6], y_train[4:6], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow(X_batch[0].reshape((img_rows, img_cols)), cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
#visualize the digits
fig = plt.figure(figsize=(10, 10)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# generate augmented plot
X_train, Y_train = datagen.flow(x_train,y_train, batch_size=100).next()
for i in range(100):
  ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
  ax.imshow(X_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
  # label the image with the target value
  ax.text(0, 7, str(np.argmax(Y_train[i])))

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Accuracy Train: 99.20% , Test: 97.73%

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 313/313 - 0s
# [[ 972    0    0    2    2    0    1    1    1    1]
#  [   0 1114    3    2    0    1    1    7    7    0]
#  [   0    0 1023    1    1    0    0    4    3    0]
#  [   0    0    3  996    0    4    0    4    3    0]
#  [   1    1    1    0  926    0    4    1    3   45]
#  [   1    1    0    4    0  875    5    2    2    2]
#  [   2    3    1    0    1    3  946    0    2    0]
#  [   1    1   16    3    0    0    0  999    0    8]
#  [   4    0   10    4    1    1    1    0  946    7]
#  [   2    0    0    3    3   14    1    5    5  976]]

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.6/dist-packages (2.4)
